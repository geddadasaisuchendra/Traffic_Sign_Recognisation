# %% [markdown]
# <html><center>
#     <h1>
#         TRAFFIC SIGN RECOGNISATION
#     </h1>
# </center>
# </html>

# %% [markdown]
# ## Importing Required Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer

# %% [markdown]
# ## Collection Of Data And Spltting Of Data

# %%
import os
from tensorflow.keras.preprocessing.image import ImageDataGenerator, img_to_array, load_img

# Define directories
data_dir = r'C:\Users\Kumar\Downloads\ct\GTSRB_Final_Training_Images\GTSRB\Final_Training\Images'

# Hyperparameters
img_height, img_width = 32, 32
batch_size = 32

# Data generators
datagen = ImageDataGenerator(rescale=1./255, validation_split=0.2)

train_gen = datagen.flow_from_directory(
    data_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='categorical',
    subset='training'
)

val_gen = datagen.flow_from_directory(
    data_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation'
)
# Out:
# Found 31368 images belonging to 43 classes.
# Found 7841 images belonging to 43 classes.

# %% [markdown]
# ## Visualizing The Dataset

# %%
import os
import matplotlib.pyplot as plt
from collections import Counter

# Define the path to the training dataset
data_dir = r'C:\Users\Kumar\Downloads\ct\GTSRB_Final_Training_Images\GTSRB\Final_Training\Images'

# Get the list of class names
class_names = os.listdir(data_dir)

# Count the number of images in each class
class_counts = Counter()
for class_name in class_names:
    class_dir = os.path.join(data_dir, class_name)
    if os.path.isdir(class_dir):
        num_images = len(os.listdir(class_dir))
        class_counts[class_name] = num_images

# Plotting the counts
plt.figure(figsize=(10, 6))
plt.bar(class_counts.keys(), class_counts.values())
plt.xlabel('Class')
plt.ylabel('Number of Images')
plt.title('Number of Images per Class in the Training Dataset')
plt.xticks(rotation=90)
plt.show()

# %%
# Get a batch of images and labels
images, labels = next(train_gen)

# Function to plot images in a grid
def plot_images(images_arr, labels_arr):
    fig, axes = plt.subplots(4, 8, figsize=(15, 8))
    axes = axes.flatten()
    for img, lbl, ax in zip(images_arr, labels_arr, axes):
        ax.imshow(img)
        ax.axis('off')
    plt.tight_layout()
    plt.show()

# Visualize the first 32 images in the training dataset
plot_images(images[:32], labels[:32])

# %% [markdown]
# ## Making the model

# %%
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(img_height, img_width, 3)),
    MaxPooling2D(pool_size=(2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D(pool_size=(2, 2)),
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D(pool_size=(2, 2)),
    Flatten(),
    Dense(512, activation='relu'),
    Dropout(0.5),
    Dense(train_gen.num_classes, activation='softmax')
])

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# C:\Users\Kumar\anaconda3\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 30, 30, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 15, 15, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 13, 13, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 6, 6, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 4, 4, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 2, 2, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │       262,656 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 43)             │        22,059 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 377,963 (1.44 MB)
#  Trainable params: 377,963 (1.44 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Augmenting the data

# %%
train_datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2,
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.1,
    zoom_range=0.1,
    horizontal_flip=False,
    fill_mode='nearest'
)

# %% [markdown]
# ## training the model

# %%
history = model.fit(
    train_gen,
    steps_per_epoch=train_gen.samples // batch_size,
    validation_data=val_gen,
    validation_steps=val_gen.samples // batch_size,
    epochs=25
)
# Out:
# Epoch 1/25
# C:\Users\Kumar\anaconda3\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 980/980 ━━━━━━━━━━━━━━━━━━━━ 296s 298ms/step - accuracy: 0.3869 - loss: 2.2048 - val_accuracy: 0.8768 - val_loss: 0.4327
# Epoch 2/25
# 980/980 ━━━━━━━━━━━━━━━━━━━━ 0s 105us/step - accuracy: 0.9688 - loss: 0.2415 - val_accuracy: 1.0000 - val_loss: 2.5034e-05
# Epoch 3/25
# C:\Users\Kumar\anaconda3\Lib\contextlib.py:158: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# 980/980 ━━━━━━━━━━━━━━━━━━━━ 31s 32ms/step - accuracy: 0.9349 - loss: 0.2110 - val_accuracy: 0.9099 - val_loss: 0.3413
# Epoch 4/25
# 980/980 ━━━━━━━━━━━━━━━━━━━━ 0s 83us/step - accuracy: 0.9688 - loss: 0.0712 - val_accuracy: 1.0000 - val_loss: 1.1921e-07
# Epoch 5/25
# 980/980 ━━━━━━━━━━━━━━━━━━━━ 29s 29ms/step - accuracy: 0.9729 - loss: 0.0931 - val_accuracy: 0.9139 - val_loss: 0.3144
# Epoch 6/25
# 980/980 ━━━━━━━━━━━━━━━━━━━━ 0s 68us/step - accuracy: 0.9688 - loss: 0.0874 - val_accuracy: 1.0000 - val_loss: 0.0937
# Epoch 7/25
# 980/980 ━━━━━━━━━━━━━━━━━━━━ 28s 29ms/step - accuracy: 0.9816 - loss: 0.0597 - val_accuracy: 0.9306 - val_loss: 0.2776
# Epoch 8/25
# 980/980 ━━━━━━━━━━━━━━━━━━━━ 0s 77us/step - accuracy: 1.0000 - loss: 0.0150 - val_accuracy: 1.0000 - val_loss: 3.1323e-04
# Epoch 9/25
# 980/980 ━━━━━━━━━━━━━━━━━━━━ 28s 28ms/step - accuracy: 0.9854 - loss: 0.0482 - val_accuracy: 0.9444 - val_loss: 0.2267
# Epoch 10/25
# 980/980 ━━━━━━━━━━━━━━━━━━━━ 0s 66us/step - accuracy: 1.0000 - loss: 0.0045 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 11/25
# 980/980 ━━━━━━━━━━━━━━━━━━━━ 30s 30ms/step - accuracy: 0.9898 - loss: 0.0358 - val_accuracy: 0.9487 - val_loss: 0.2395
# Epoch 12/25
# 980/980 ━━━━━━━━━━━━━━━━━━━━ 0s 72us/step - accuracy: 1.0000 - loss: 0.0057 - val_accuracy: 1.0000 - val_loss: 7.4741e-05
# Epoch 13/25
# 980/980 ━━━━━━━━━━━━━━━━━━━━ 30s 30ms/step - accuracy: 0.9868 - loss: 0.0416 - val_accuracy: 0.9540 - val_loss: 0.2049
# Epoch 14/25
# 980/980 ━━━━━━━━━━━━━━━━━━━━ 0s 65us/step - accuracy: 1.0000 - loss: 0.0452 - val_accuracy: 1.0000 - val_loss: 0.0115
# Epoch 15/25
# 980/980 ━━━━━━━━━━━━━━━━━━━━ 27s 28ms/step - accuracy: 0.9889 - loss: 0.0361 - val_accuracy: 0.9366 - val_loss: 0.3008
# Epoch 16/25
# 980/980 ━━━━━━━━━━━━━━━━━━━━ 0s 77us/step - accuracy: 1.0000 - loss: 0.0326 - val_accuracy: 1.0000 - val_loss: 9.2023e-04
# Epoch 17/25
# 980/980 ━━━━━━━━━━━━━━━━━━━━ 28s 29ms/step - accuracy: 0.9906 - loss: 0.0314 - val_accuracy: 0.9411 - val_loss: 0.3232
# Epoch 18/25
# 980/980 ━━━━━━━━━━━━━━━━━━━━ 0s 106us/step - accuracy: 0.9688 - loss: 0.0958 - val_accuracy: 1.0000 - val_loss: 0.0573
# Epoch 19/25
# 980/980 ━━━━━━━━━━━━━━━━━━━━ 29s 30ms/step - accuracy: 0.9921 - loss: 0.0241 - val_accuracy: 0.9245 - val_loss: 0.4479
# Epoch 20/25
# 980/980 ━━━━━━━━━━━━━━━━━━━━ 0s 68us/step - accuracy: 1.0000 - loss: 0.0079 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 21/25
# 980/980 ━━━━━━━━━━━━━━━━━━━━ 28s 29ms/step - accuracy: 0.9939 - loss: 0.0201 - val_accuracy: 0.9364 - val_loss: 0.2961
# Epoch 22/25
# 980/980 ━━━━━━━━━━━━━━━━━━━━ 0s 63us/step - accuracy: 1.0000 - loss: 0.0140 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 23/25
# 980/980 ━━━━━━━━━━━━━━━━━━━━ 29s 30ms/step - accuracy: 0.9932 - loss: 0.0214 - val_accuracy: 0.9429 - val_loss: 0.3577
# Epoch 24/25
# 980/980 ━━━━━━━━━━━━━━━━━━━━ 0s 69us/step - accuracy: 1.0000 - loss: 5.1668e-05 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 25/25
# 980/980 ━━━━━━━━━━━━━━━━━━━━ 170s 174ms/step - accuracy: 0.9953 - loss: 0.0167 - val_accuracy: 0.9221 - val_loss: 0.4469

# %% [markdown]
# ## Evaluating the model

# %%
# Evaluate the model on the validation set
val_loss, val_accuracy = model.evaluate(val_gen, steps=val_gen.samples // batch_size)
print(f'Validation loss: {val_loss}')
print(f'Validation accuracy: {val_accuracy}')
# Out:
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 7s 30ms/step - accuracy: 0.9178 - loss: 0.4579
# Validation loss: 0.44685521721839905
# Validation accuracy: 0.922066330909729

# %% [markdown]
# ## Visulisation of Evalution

# %%
# Plot training & validation accuracy values
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.show()

# %%
model.save('traffic_sign_recognition_model.keras')

# %% [markdown]
# ## Running the Predictions

# %%
from tensorflow.keras.models import load_model
from PIL import Image

# Load the trained model
model = load_model('traffic_sign_recognition_model.keras')

# Load a sample image to predict
sample_image_path = r"C:\Users\Kumar\Downloads\istockphoto-486744506-1024x1024.jpg"
#showing image
sample_image = Image.open(sample_image_path)
plt.imshow(sample_image)
plt.show()
sample_image = load_img(sample_image_path, target_size=(img_height, img_width))
sample_image = img_to_array(sample_image) / 255.0
sample_image = np.expand_dims(sample_image, axis=0)

# Predict the class
prediction = model.predict(sample_image)
predicted_class = np.argmax(prediction)
if predicted_class==0:
    print("Speed limit (20km/h)")
elif predicted_class==1:
    print('Speed limit (30km/h)')
elif predicted_class==2:
    print('Speed limit (50km/h)')
elif predicted_class==3:
    print('Speed limit (60km/h)')
elif predicted_class==4:
    print('Speed limit (70km/h)')
elif predicted_class==5:
    print('Speed limit (80km/h)')
elif predicted_class==6:
    print('End of speed limit (80km/h)')
elif predicted_class==7:
    print('Speed limit (100km/h)')
elif predicted_class==8:
    print('Speed limit (120km/h)')
elif predicted_class==9:
    print('No passing')
elif predicted_class==10:
    print('No passing veh over 3.5 tons')
elif predicted_class==11:
    print('Right-of-way at intersection')
elif predicted_class==12:
    print('Priority road')
elif predicted_class==13:
    print('Yield')
elif predicted_class==14:
    print('Stop')
elif predicted_class==15:
    print('No vehicles')
elif predicted_class==16:
    print('Veh > 3.5 tons prohibited')
elif predicted_class==17:
    print('No entry')
elif predicted_class==18:
    print('General caution')
elif predicted_class==19:
    print('Dangerous curve left')
elif predicted_class==20:
    print('Dangerous curve right')
elif predicted_class==21:
    print('Double curve')
elif predicted_class==22:
    print('Bumpy road')
elif predicted_class==23:
    print('Slippery road')
elif predicted_class==24:
    print('Road narrows on the right')
elif predicted_class==25:
    print('Road work')
elif predicted_class==26:
    print('Traffic signals')
elif predicted_class==27:
    print('Pedestrians')
elif predicted_class==28:
    print('Children crossing')
elif predicted_class==29:
    print('Bicycles crossing')
elif predicted_class==30:
    print('Beware of ice/snow')
elif predicted_class==31:
    print('Wild animals crossing')
elif predicted_class==32:
    print('End speed + passing limits')
elif predicted_class==33:
    print('Turn right ahead')
elif predicted_class==34:
    print('Turn left ahead')
elif predicted_class==35:
    print('Ahead only')
elif predicted_class==36:
    print('Go straight or right')
elif predicted_class==37:
    print('Go straight or left')
elif predicted_class==38:
    print('Keep right')
elif predicted_class==39:
    print('Keep left')
elif predicted_class==40:
    print('Roundabout mandatory')
elif predicted_class==41:
    print('End of no passing')
else:
    print('End no passing veh > 3.5 tons')

#print(f'Predicted class: {predicted_class}')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# Stop
